# %%
import pandas as pd
import os

# %%
file1 = os.path.join('csv','JC-201901-citibike-tripdata.csv')

# %%
file2 = os.path.join("csv","JC-201902-citibike-tripdata.csv")

# %%
file3 = os.path.join("csv","JC-201903-citibike-tripdata.csv")

# %%
file4 = os.path.join("csv","JC-201904-citibike-tripdata.csv")

# %%
file5 = os.path.join("csv","JC-201905-citibike-tripdata.csv")

# %%
file6 = os.path.join("csv","JC-201906-citibike-tripdata.csv")

# %%
df1 = pd.read_csv(file1)

# %%
df2 = pd.read_csv(file2)

# %%
df3 = pd.read_csv(file3)

# %%
df4 = pd.read_csv(file4)

# %%
df5 = pd.read_csv(file5)

# %%
df6 = pd.read_csv(file6)

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6])

# %%
df.head(10)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# 5           737  2019-01-01 12:56:53.2040  2019-01-01 13:09:11.0400
# 6           917  2019-01-01 13:03:44.7760  2019-01-01 13:19:02.7690
# 7          3248  2019-01-01 13:12:03.1280  2019-01-01 14:06:12.0400
# 8          3168  2019-01-01 13:13:12.0450  2019-01-01 14:06:00.4110
# 9           353  2019-01-01 17:07:44.6670  2019-01-01 17:13:38.2640
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# ...

# %%
df.count()
# Out:
# tripduration               170468
# starttime                  170468
# stoptime                   170468
# start station id           170468
# start station name         170468
# start station latitude     170468
# start station longitude    170468
# end station id             170468
# end station name           170468
# end station latitude       170468
# end station longitude      170468
# bikeid                     170468
# usertype                   170468
# birth year                 170468
# gender                     170468
# dtype: int64

# %%
# df.to_csv('csv/citibikedata.csv',index=False,header=True)

# %%
df['gender'].value_counts()
# Out:
# 1    124066
# 2     36166
# 0     10236
# Name: gender, dtype: int64

# %%
df['Gender'] = df['gender'].replace([0,1,2],['Unknown','Male','Female'])

# %%
df['Gender'].value_counts()
# Out:
# Male       124066
# Female      36166
# Unknown     10236
# Name: Gender, dtype: int64

# %%
df.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender', 'Gender'],
#       dtype='object')

# %%
del df['gender']

# %%
df.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'Gender'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
df['age'] = 2019-df['birth year']

# %%
df.head(5)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
df.to_csv('csv/citibikedata.csv',index=False,header=True)
